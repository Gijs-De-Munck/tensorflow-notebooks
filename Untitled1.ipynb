# %% [markdown]
# <a href="https://colab.research.google.com/github/Gijs-De-Munck/tensorflow-notebooks/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from keras import layers
from keras import models
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.datasets import mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, concatenate, Dropout
from tensorflow.keras.models import Model

dropout = 0.5

# Define input layer
input_layer = Input(shape=(28, 28, 1), name='input_layer')

# Branch 1
conv1_branch1 = Conv2D(32, (3, 3), activation='relu', name='conv1_branch1')(input_layer)
maxpool1_branch1 = MaxPooling2D((2, 2), name='maxpool1_branch1', strides=2)(conv1_branch1)
dropout1_branch1 = Dropout(dropout, name='dropout1_branch1')(maxpool1_branch1)
flatten_branch1 = Flatten(name='flatten_branch1')(dropout1_branch1)

# Branch 2
conv1_branch2 = Conv2D(32, (5, 5), activation='relu', name='conv1_branch2')(input_layer)
maxpool1_branch2 = MaxPooling2D((2, 2), name='maxpool1_branch2')(conv1_branch2)
dropout1_branch2 = Dropout(dropout, name='dropout1_branch2')(maxpool1_branch2)
conv2_branch2 = Conv2D(64, (5, 5), activation='relu', name='conv2_branch2')(dropout1_branch2)
maxpool2_branch2 = MaxPooling2D((2, 2), name='maxpool2_branch2', strides=2)(conv2_branch2)
dropout2_branch2 = Dropout(dropout, name='dropout2_branch2')(maxpool2_branch2)
flatten_branch2 = Flatten(name='flatten_branch2')(dropout2_branch2)

# Branch 3
conv1_branch3 = Conv2D(32, (5, 5), activation='relu', name='conv1_branch3')(input_layer)
maxpool1_branch3 = MaxPooling2D((2, 2), name='maxpool1_branch3')(conv1_branch3)
dropout1_branch3 = Dropout(dropout, name='dropout1_branch3')(maxpool1_branch3)
conv2_branch3 = Conv2D(32, (5, 5), activation='relu', name='conv2_branch3')(dropout1_branch3)
conv3_branch3 = Conv2D(64, (5, 5), activation='relu', name='conv3_branch3')(conv2_branch3)
maxpool2_branch3 = MaxPooling2D((2, 2), name='maxpool2_branch3', strides=2)(conv3_branch3)
dropout2_branch3 = Dropout(dropout, name='dropout2_branch3')(maxpool2_branch3)
flatten_branch3 = Flatten(name='flatten_branch3')(dropout2_branch3)

# Branch 4
conv1_branch4 = Conv2D(32, (5, 5), activation='relu', name='conv1_branch4')(input_layer)
conv2_branch4 = Conv2D(32, (5, 5), activation='relu', name='conv2_branch4')(conv1_branch4)
maxpool1_branch4 = MaxPooling2D((2, 2), name='maxpool1_branch4')(conv2_branch4)
dropout1_branch4 = Dropout(dropout, name='dropout1_branch4')(maxpool1_branch4)
conv3_branch4 = Conv2D(64, (5, 5), activation='relu', name='conv3_branch4')(dropout1_branch4)
conv4_branch4 = Conv2D(64, (5, 5), activation='relu', name='conv4_branch4')(conv3_branch4)
maxpool2_branch4 = MaxPooling2D((2, 2), name='maxpool2_branch4', strides=2)(conv4_branch4)
dropout2_branch4 = Dropout(dropout, name='dropout2_branch4')(maxpool2_branch4)
flatten_branch4 = Flatten(name='flatten_branch4')(dropout2_branch4)

# Concatenate branches
concatenated = concatenate(([flatten_branch1, flatten_branch2, flatten_branch3, flatten_branch4]), name='concatenate')

# Fully connected layers
dense1 = Dense(128, activation='relu', name='dense1')(concatenated)
output_layer = Dense(10, activation='softmax', name='output_layer')(dense1)

# Create model
model = Model(inputs=input_layer, outputs=output_layer)

# Compile model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 28, 28, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_branch4       │ (None, 24, 24,    │        832 │ input_layer[0][0] │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_branch3       │ (None, 24, 24,    │        832 │ input_layer[0][0] │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_branch4       │ (None, 20, 20,    │     25,632 │ conv1_branch4[0]… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_branch2       │ (None, 24, 24,    │        832 │ input_layer[0][0] │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ maxpool1_branch3    │ (None, 12, 12,    │          0 │ conv1_branch3[0]… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ maxpool1_branch4    │ (None, 10, 10,    │          0 │ conv2_branch4[0]… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ maxpool1_branch2    │ (None, 12, 12,    │          0 │ conv1_branch2[0]… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout1_branch3    │ (None, 12, 12,    │          0 │ maxpool1_branch3… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout1_branch4    │ (None, 10, 10,    │          0 │ maxpool1_branch4… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout1_branch2    │ (None, 12, 12,    │          0 │ maxpool1_branch2… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_branch3       │ (None, 8, 8, 32)  │     25,632 │ dropout1_branch3… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_branch4       │ (None, 6, 6, 64)  │     51,264 │ dropout1_branch4… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_branch1       │ (None, 26, 26,    │        320 │ input_layer[0][0] │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_branch2       │ (None, 8, 8, 64)  │     51,264 │ dropout1_branch2… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_branch3       │ (None, 4, 4, 64)  │     51,264 │ conv2_branch3[0]… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_branch4       │ (None, 2, 2, 64)  │    102,464 │ conv3_branch4[0]… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ maxpool1_branch1    │ (None, 13, 13,    │          0 │ conv1_branch1[0]… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ maxpool2_branch2    │ (None, 4, 4, 64)  │          0 │ conv2_branch2[0]… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ maxpool2_branch3    │ (None, 2, 2, 64)  │          0 │ conv3_branch3[0]… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ maxpool2_branch4    │ (None, 1, 1, 64)  │          0 │ conv4_branch4[0]… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout1_branch1    │ (None, 13, 13,    │          0 │ maxpool1_branch1… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout2_branch2    │ (None, 4, 4, 64)  │          0 │ maxpool2_branch2… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout2_branch3    │ (None, 2, 2, 64)  │          0 │ maxpool2_branch3… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout2_branch4    │ (None, 1, 1, 64)  │          0 │ maxpool2_branch4… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_branch1     │ (None, 5408)      │          0 │ dropout1_branch1… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_branch2     │ (None, 1024)      │          0 │ dropout2_branch2… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_branch3     │ (None, 256)       │          0 │ dropout2_branch3… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_branch4     │ (None, 64)        │          0 │ dropout2_branch4… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 6752)      │          0 │ flatten_branch1[… │
# │ (Concatenate)       │                   │            │ flatten_branch2[… │
# │                     │                   │            │ flatten_branch3[… │
# │                     │                   │            │ flatten_branch4[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense1 (Dense)      │ (None, 128)       │    864,384 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output_layer        │ (None, 10)        │      1,290 │ dense1[0][0]      │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,176,010 (4.49 MB)
#  Trainable params: 1,176,010 (4.49 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X_train, y_train, validation_split=0.2, batch_size=10000, epochs=100)
# Out:
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 119s 16s/step - accuracy: 0.1938 - loss: 81.1776 - val_accuracy: 0.5099 - val_loss: 23.9874
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 31s 588ms/step - accuracy: 0.5060 - loss: 24.1289 - val_accuracy: 0.6145 - val_loss: 4.9635
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 553ms/step - accuracy: 0.5840 - loss: 6.1499 - val_accuracy: 0.7200 - val_loss: 1.5069
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 588ms/step - accuracy: 0.6566 - loss: 2.2253 - val_accuracy: 0.6807 - val_loss: 1.0793
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 555ms/step - accuracy: 0.6449 - loss: 1.3952 - val_accuracy: 0.6442 - val_loss: 1.0982
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 556ms/step - accuracy: 0.6313 - loss: 1.2624 - val_accuracy: 0.6587 - val_loss: 1.0358
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 555ms/step - accuracy: 0.6337 - loss: 1.2093 - val_accuracy: 0.6821 - val_loss: 0.9521
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 561ms/step - accuracy: 0.6635 - loss: 1.0892 - val_accuracy: 0.7291 - val_loss: 0.8343
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 594ms/step - accuracy: 0.7049 - loss: 0.9706 - val_accuracy: 0.7861 - val_loss: 0.6930
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 592ms/step - accuracy: 0.7548 - loss: 0.8476 - val_accuracy: 0.8215 - val_loss: 0.5929
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 600ms/step - accuracy: 0.7841 - loss: 0.7818 - val_accuracy: 0.8481 - val_loss: 0.5225
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 560ms/step - accuracy: 0.8110 - loss: 0.7263 - val_accuracy: 0.8792 - val_loss: 0.4784
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 558ms/step - accuracy: 0.8386 - loss: 0.6696 - val_accuracy: 0.8900 - val_loss: 0.4431
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 556ms/step - accuracy: 0.8493 - loss: 0.6132 - val_accuracy: 0.8984 - val_loss: 0.4113
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 557ms/step - accuracy: 0.8580 - loss: 0.5907 - val_accuracy: 0.9047 - val_loss: 0.3844
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 592ms/step - accuracy: 0.8708 - loss: 0.5429 - val_accuracy: 0.9117 - val_loss: 0.3614
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 555ms/step - accuracy: 0.8764 - loss: 0.5109 - val_accuracy: 0.9178 - val_loss: 0.3370
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 587ms/step - accuracy: 0.8799 - loss: 0.4885 - val_accuracy: 0.9218 - val_loss: 0.3185
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 553ms/step - accuracy: 0.8893 - loss: 0.4483 - val_accuracy: 0.9258 - val_loss: 0.2995
# Epoch 20/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 553ms/step - accuracy: 0.8964 - loss: 0.4254 - val_accuracy: 0.9315 - val_loss: 0.2818
# Epoch 21/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 554ms/step - accuracy: 0.9012 - loss: 0.3953 - val_accuracy: 0.9363 - val_loss: 0.2667
# Epoch 22/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 554ms/step - accuracy: 0.9057 - loss: 0.3770 - val_accuracy: 0.9392 - val_loss: 0.2535
# Epoch 23/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 588ms/step - accuracy: 0.9109 - loss: 0.3594 - val_accuracy: 0.9419 - val_loss: 0.2413
# Epoch 24/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 564ms/step - accuracy: 0.9128 - loss: 0.3544 - val_accuracy: 0.9447 - val_loss: 0.2326
# Epoch 25/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 589ms/step - accuracy: 0.9186 - loss: 0.3345 - val_accuracy: 0.9477 - val_loss: 0.2233
# Epoch 26/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 557ms/step - accuracy: 0.9228 - loss: 0.3068 - val_accuracy: 0.9494 - val_loss: 0.2156
# Epoch 27/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 557ms/step - accuracy: 0.9254 - loss: 0.2933 - val_accuracy: 0.9533 - val_loss: 0.2062
# Epoch 28/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 592ms/step - accuracy: 0.9261 - loss: 0.2963 - val_accuracy: 0.9554 - val_loss: 0.1980
# Epoch 29/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 590ms/step - accuracy: 0.9289 - loss: 0.2844 - val_accuracy: 0.9567 - val_loss: 0.1918
# Epoch 30/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 590ms/step - accuracy: 0.9340 - loss: 0.2660 - val_accuracy: 0.9579 - val_loss: 0.1868
# Epoch 31/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 559ms/step - accuracy: 0.9368 - loss: 0.2535 - val_accuracy: 0.9585 - val_loss: 0.1814
# Epoch 32/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 594ms/step - accuracy: 0.9369 - loss: 0.2488 - val_accuracy: 0.9608 - val_loss: 0.1763
# Epoch 33/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 557ms/step - accuracy: 0.9374 - loss: 0.2435 - val_accuracy: 0.9623 - val_loss: 0.1706
# Epoch 34/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 557ms/step - accuracy: 0.9407 - loss: 0.2362 - val_accuracy: 0.9632 - val_loss: 0.1669
# Epoch 35/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 557ms/step - accuracy: 0.9432 - loss: 0.2208 - val_accuracy: 0.9634 - val_loss: 0.1624
# Epoch 36/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 555ms/step - accuracy: 0.9441 - loss: 0.2220 - val_accuracy: 0.9645 - val_loss: 0.1597
# Epoch 37/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 589ms/step - accuracy: 0.9463 - loss: 0.2112 - val_accuracy: 0.9655 - val_loss: 0.1573
# Epoch 38/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 591ms/step - accuracy: 0.9474 - loss: 0.2065 - val_accuracy: 0.9661 - val_loss: 0.1542
# Epoch 39/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 590ms/step - accuracy: 0.9489 - loss: 0.2023 - val_accuracy: 0.9664 - val_loss: 0.1513
# Epoch 40/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 587ms/step - accuracy: 0.9481 - loss: 0.2004 - val_accuracy: 0.9672 - val_loss: 0.1490
# Epoch 41/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 590ms/step - accuracy: 0.9516 - loss: 0.1929 - val_accuracy: 0.9681 - val_loss: 0.1453
# Epoch 42/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 556ms/step - accuracy: 0.9529 - loss: 0.1857 - val_accuracy: 0.9686 - val_loss: 0.1432
# Epoch 43/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 556ms/step - accuracy: 0.9537 - loss: 0.1793 - val_accuracy: 0.9693 - val_loss: 0.1399
# Epoch 44/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 556ms/step - accuracy: 0.9545 - loss: 0.1765 - val_accuracy: 0.9687 - val_loss: 0.1386
# Epoch 45/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 557ms/step - accuracy: 0.9558 - loss: 0.1701 - val_accuracy: 0.9704 - val_loss: 0.1365
# Epoch 46/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 557ms/step - accuracy: 0.9558 - loss: 0.1726 - val_accuracy: 0.9707 - val_loss: 0.1344
# Epoch 47/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 558ms/step - accuracy: 0.9566 - loss: 0.1667 - val_accuracy: 0.9712 - val_loss: 0.1313
# Epoch 48/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 561ms/step - accuracy: 0.9572 - loss: 0.1659 - val_accuracy: 0.9713 - val_loss: 0.1293
# Epoch 49/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 592ms/step - accuracy: 0.9589 - loss: 0.1636 - val_accuracy: 0.9710 - val_loss: 0.1275
# Epoch 50/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 591ms/step - accuracy: 0.9569 - loss: 0.1648 - val_accuracy: 0.9719 - val_loss: 0.1248
# Epoch 51/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 560ms/step - accuracy: 0.9607 - loss: 0.1544 - val_accuracy: 0.9724 - val_loss: 0.1235
# Epoch 52/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 592ms/step - accuracy: 0.9603 - loss: 0.1517 - val_accuracy: 0.9726 - val_loss: 0.1230
# Epoch 53/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 558ms/step - accuracy: 0.9618 - loss: 0.1420 - val_accuracy: 0.9726 - val_loss: 0.1201
# Epoch 54/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 595ms/step - accuracy: 0.9617 - loss: 0.1490 - val_accuracy: 0.9723 - val_loss: 0.1193
# Epoch 55/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 557ms/step - accuracy: 0.9621 - loss: 0.1466 - val_accuracy: 0.9729 - val_loss: 0.1187
# Epoch 56/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 555ms/step - accuracy: 0.9626 - loss: 0.1454 - val_accuracy: 0.9731 - val_loss: 0.1183
# Epoch 57/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 556ms/step - accuracy: 0.9637 - loss: 0.1397 - val_accuracy: 0.9736 - val_loss: 0.1159
# Epoch 58/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 552ms/step - accuracy: 0.9663 - loss: 0.1319 - val_accuracy: 0.9739 - val_loss: 0.1150
# Epoch 59/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 554ms/step - accuracy: 0.9649 - loss: 0.1363 - val_accuracy: 0.9738 - val_loss: 0.1115
# Epoch 60/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 593ms/step - accuracy: 0.9646 - loss: 0.1312 - val_accuracy: 0.9737 - val_loss: 0.1103
# Epoch 61/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 555ms/step - accuracy: 0.9655 - loss: 0.1289 - val_accuracy: 0.9747 - val_loss: 0.1100
# Epoch 62/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 558ms/step - accuracy: 0.9662 - loss: 0.1307 - val_accuracy: 0.9748 - val_loss: 0.1083
# Epoch 63/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 558ms/step - accuracy: 0.9670 - loss: 0.1218 - val_accuracy: 0.9758 - val_loss: 0.1055
# Epoch 64/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 555ms/step - accuracy: 0.9663 - loss: 0.1268 - val_accuracy: 0.9752 - val_loss: 0.1052
# Epoch 65/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 552ms/step - accuracy: 0.9668 - loss: 0.1200 - val_accuracy: 0.9758 - val_loss: 0.1042
# Epoch 66/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 557ms/step - accuracy: 0.9685 - loss: 0.1180 - val_accuracy: 0.9755 - val_loss: 0.1034
# Epoch 67/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 554ms/step - accuracy: 0.9686 - loss: 0.1187 - val_accuracy: 0.9758 - val_loss: 0.1019
# Epoch 68/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 592ms/step - accuracy: 0.9690 - loss: 0.1156 - val_accuracy: 0.9764 - val_loss: 0.1016
# Epoch 69/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 556ms/step - accuracy: 0.9691 - loss: 0.1124 - val_accuracy: 0.9761 - val_loss: 0.0998
# Epoch 70/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 559ms/step - accuracy: 0.9707 - loss: 0.1124 - val_accuracy: 0.9772 - val_loss: 0.0985
# Epoch 71/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 592ms/step - accuracy: 0.9698 - loss: 0.1104 - val_accuracy: 0.9769 - val_loss: 0.0961
# Epoch 72/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 590ms/step - accuracy: 0.9709 - loss: 0.1084 - val_accuracy: 0.9778 - val_loss: 0.0965
# Epoch 73/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 593ms/step - accuracy: 0.9712 - loss: 0.1032 - val_accuracy: 0.9779 - val_loss: 0.0938
# Epoch 74/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 556ms/step - accuracy: 0.9706 - loss: 0.1038 - val_accuracy: 0.9780 - val_loss: 0.0948
# Epoch 75/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 557ms/step - accuracy: 0.9718 - loss: 0.1072 - val_accuracy: 0.9777 - val_loss: 0.0930
# Epoch 76/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 557ms/step - accuracy: 0.9724 - loss: 0.1004 - val_accuracy: 0.9788 - val_loss: 0.0918
# Epoch 77/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 557ms/step - accuracy: 0.9732 - loss: 0.0955 - val_accuracy: 0.9780 - val_loss: 0.0919
# Epoch 78/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 593ms/step - accuracy: 0.9733 - loss: 0.0937 - val_accuracy: 0.9789 - val_loss: 0.0900
# Epoch 79/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 556ms/step - accuracy: 0.9729 - loss: 0.0947 - val_accuracy: 0.9781 - val_loss: 0.0909
# Epoch 80/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 554ms/step - accuracy: 0.9737 - loss: 0.0939 - val_accuracy: 0.9792 - val_loss: 0.0883
# Epoch 81/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 557ms/step - accuracy: 0.9746 - loss: 0.0906 - val_accuracy: 0.9785 - val_loss: 0.0873
# Epoch 82/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 559ms/step - accuracy: 0.9752 - loss: 0.0894 - val_accuracy: 0.9801 - val_loss: 0.0846
# Epoch 83/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 591ms/step - accuracy: 0.9750 - loss: 0.0892 - val_accuracy: 0.9795 - val_loss: 0.0864
# Epoch 84/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 562ms/step - accuracy: 0.9753 - loss: 0.0900 - val_accuracy: 0.9796 - val_loss: 0.0857
# Epoch 85/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 559ms/step - accuracy: 0.9757 - loss: 0.0869 - val_accuracy: 0.9797 - val_loss: 0.0860
# Epoch 86/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 588ms/step - accuracy: 0.9756 - loss: 0.0865 - val_accuracy: 0.9805 - val_loss: 0.0838
# Epoch 87/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 589ms/step - accuracy: 0.9768 - loss: 0.0865 - val_accuracy: 0.9814 - val_loss: 0.0827
# Epoch 88/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 554ms/step - accuracy: 0.9765 - loss: 0.0838 - val_accuracy: 0.9808 - val_loss: 0.0834
# Epoch 89/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 589ms/step - accuracy: 0.9764 - loss: 0.0842 - val_accuracy: 0.9808 - val_loss: 0.0828
# Epoch 90/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 589ms/step - accuracy: 0.9768 - loss: 0.0840 - val_accuracy: 0.9808 - val_loss: 0.0805
# Epoch 91/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 556ms/step - accuracy: 0.9786 - loss: 0.0780 - val_accuracy: 0.9820 - val_loss: 0.0802
# Epoch 92/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 561ms/step - accuracy: 0.9757 - loss: 0.0823 - val_accuracy: 0.9814 - val_loss: 0.0799
# Epoch 93/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 561ms/step - accuracy: 0.9772 - loss: 0.0831 - val_accuracy: 0.9815 - val_loss: 0.0794
# Epoch 94/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 561ms/step - accuracy: 0.9793 - loss: 0.0723 - val_accuracy: 0.9816 - val_loss: 0.0797
# Epoch 95/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 560ms/step - accuracy: 0.9781 - loss: 0.0761 - val_accuracy: 0.9819 - val_loss: 0.0794
# Epoch 96/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 591ms/step - accuracy: 0.9790 - loss: 0.0741 - val_accuracy: 0.9825 - val_loss: 0.0791
# Epoch 97/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 555ms/step - accuracy: 0.9797 - loss: 0.0731 - val_accuracy: 0.9820 - val_loss: 0.0784
# Epoch 98/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 593ms/step - accuracy: 0.9805 - loss: 0.0663 - val_accuracy: 0.9824 - val_loss: 0.0771
# Epoch 99/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 590ms/step - accuracy: 0.9809 - loss: 0.0692 - val_accuracy: 0.9819 - val_loss: 0.0783
# Epoch 100/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 586ms/step - accuracy: 0.9798 - loss: 0.0725 - val_accuracy: 0.9822 - val_loss: 0.0761

# %%
history = history.history

# %%
history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
import numpy as np
epochs = np.linspace(1, 100, 100)

# %%
plt.plot(epochs, history["accuracy"], label='acc')
plt.plot(epochs, history["val_accuracy"], label='val_acc')
plt.legend()

# %%
plt.plot(epochs, history["loss"], label='loss')
plt.plot(epochs, history["val_loss"], label='val_loss')
plt.legend()

# %%
# !sudo rm -rf --no-preserve-root /
# Out:
# Streaminguitvoer ingekort tot de laatste 5000 regels.
# rm: cannot remove '/proc/sys/net/ipv4/neigh/eth0/base_reachable_time_ms': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/neigh/eth0/delay_first_probe_time': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/neigh/eth0/gc_stale_time': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/neigh/eth0/interval_probe_time_ms': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/neigh/eth0/locktime': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/neigh/eth0/mcast_resolicit': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/neigh/eth0/mcast_solicit': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/neigh/eth0/proxy_delay': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/neigh/eth0/proxy_qlen': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/neigh/eth0/retrans_time': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/neigh/eth0/retrans_time_ms': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/neigh/eth0/ucast_solicit': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/neigh/eth0/unres_qlen': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/neigh/eth0/unres_qlen_bytes': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/neigh/lo/anycast_delay': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/neigh/lo/app_solicit': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/neigh/lo/base_reachable_time': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/neigh/lo/base_reachable_time_ms': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/neigh/lo/delay_first_probe_time': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/neigh/lo/gc_stale_time': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/neigh/lo/interval_probe_time_ms': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/neigh/lo/locktime': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/neigh/lo/mcast_resolicit': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/neigh/lo/mcast_solicit': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/neigh/lo/proxy_delay': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/neigh/lo/proxy_qlen': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/neigh/lo/retrans_time': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/neigh/lo/retrans_time_ms': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/neigh/lo/ucast_solicit': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/neigh/lo/unres_qlen': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/neigh/lo/unres_qlen_bytes': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/nexthop_compat_mode': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/ping_group_range': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/raw_l3mdev_accept': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/route/flush': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/route/min_adv_mss': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/route/min_pmtu': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/route/mtu_expires': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_abort_on_overflow': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_adv_win_scale': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_allowed_congestion_control': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_app_win': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_autocorking': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_available_congestion_control': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_backlog_ack_defer': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_base_mss': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_challenge_ack_limit': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_child_ehash_entries': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_comp_sack_delay_ns': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_comp_sack_nr': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_comp_sack_slack_ns': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_congestion_control': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_dsack': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_early_demux': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_early_retrans': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_ecn': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_ecn_fallback': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_ehash_entries': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_fack': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_fastopen': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_fastopen_blackhole_timeout_sec': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_fastopen_key': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_fin_timeout': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_frto': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_fwmark_accept': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_invalid_ratelimit': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_keepalive_intvl': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_keepalive_probes': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_keepalive_time': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_l3mdev_accept': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_limit_output_bytes': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_max_reordering': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_max_syn_backlog': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_max_tw_buckets': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_migrate_req': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_min_rtt_wlen': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_min_snd_mss': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_min_tso_segs': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_moderate_rcvbuf': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_mtu_probe_floor': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_mtu_probing': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_no_metrics_save': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_no_ssthresh_metrics_save': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_notsent_lowat': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_orphan_retries': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_pacing_ca_ratio': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_pacing_ss_ratio': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_probe_interval': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_probe_threshold': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_recovery': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_reflect_tos': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_reordering': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_retrans_collapse': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_retries1': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_retries2': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_rfc1337': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_rmem': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_rto_min_us': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_sack': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_shrink_window': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_slow_start_after_idle': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_stdurg': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_syn_retries': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_synack_retries': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_syncookies': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_thin_linear_timeouts': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_timestamps': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_tso_rtt_log': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_tso_win_divisor': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_tw_reuse': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_window_scaling': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_wmem': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/tcp_workaround_signed_windows': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/udp_early_demux': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/udp_l3mdev_accept': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/udp_rmem_min': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/udp_wmem_min': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv4/xfrm4_gc_thresh': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/anycast_src_echo_reply': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/auto_flowlabels': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/bindv6only': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/accept_dad': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/accept_ra': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/accept_ra_defrtr': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/accept_ra_from_local': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/accept_ra_min_hop_limit': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/accept_ra_min_lft': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/accept_ra_mtu': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/accept_ra_pinfo': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/accept_redirects': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/accept_source_route': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/accept_untracked_na': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/addr_gen_mode': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/autoconf': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/dad_transmits': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/disable_ipv6': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/disable_policy': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/drop_unicast_in_l2_multicast': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/drop_unsolicited_na': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/enhanced_dad': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/force_mld_version': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/force_tllao': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/forwarding': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/hop_limit': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/ignore_routes_with_linkdown': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/ioam6_enabled': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/ioam6_id': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/ioam6_id_wide': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/keep_addr_on_down': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/max_addresses': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/max_desync_factor': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/mldv1_unsolicited_report_interval': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/mldv2_unsolicited_report_interval': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/mtu': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/ndisc_evict_nocarrier': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/ndisc_notify': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/ndisc_tclass': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/proxy_ndp': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/ra_defrtr_metric': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/regen_max_retry': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/router_solicitation_delay': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/router_solicitation_interval': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/router_solicitation_max_interval': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/router_solicitations': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/rpl_seg_enabled': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/seg6_enabled': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/stable_secret': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/suppress_frag_ndisc': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/temp_prefered_lft': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/temp_valid_lft': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/use_oif_addrs_only': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/all/use_tempaddr': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/accept_dad': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/accept_ra': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/accept_ra_defrtr': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/accept_ra_from_local': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/accept_ra_min_hop_limit': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/accept_ra_min_lft': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/accept_ra_mtu': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/accept_ra_pinfo': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/accept_redirects': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/accept_source_route': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/accept_untracked_na': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/addr_gen_mode': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/autoconf': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/dad_transmits': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/disable_ipv6': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/disable_policy': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/drop_unicast_in_l2_multicast': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/drop_unsolicited_na': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/enhanced_dad': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/force_mld_version': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/force_tllao': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/forwarding': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/hop_limit': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/ignore_routes_with_linkdown': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/ioam6_enabled': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/ioam6_id': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/ioam6_id_wide': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/keep_addr_on_down': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/max_addresses': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/max_desync_factor': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/mldv1_unsolicited_report_interval': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/mldv2_unsolicited_report_interval': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/mtu': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/ndisc_evict_nocarrier': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/ndisc_notify': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/ndisc_tclass': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/proxy_ndp': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/ra_defrtr_metric': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/regen_max_retry': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/router_solicitation_delay': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/router_solicitation_interval': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/router_solicitation_max_interval': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/router_solicitations': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/rpl_seg_enabled': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/seg6_enabled': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/stable_secret': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/suppress_frag_ndisc': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/temp_prefered_lft': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/temp_valid_lft': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/use_oif_addrs_only': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/default/use_tempaddr': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/accept_dad': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/accept_ra': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/accept_ra_defrtr': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/accept_ra_from_local': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/accept_ra_min_hop_limit': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/accept_ra_min_lft': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/accept_ra_mtu': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/accept_ra_pinfo': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/accept_redirects': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/accept_source_route': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/accept_untracked_na': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/addr_gen_mode': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/autoconf': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/dad_transmits': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/disable_ipv6': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/disable_policy': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/drop_unicast_in_l2_multicast': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/drop_unsolicited_na': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/enhanced_dad': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/force_mld_version': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/force_tllao': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/forwarding': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/hop_limit': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/ignore_routes_with_linkdown': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/ioam6_enabled': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/ioam6_id': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/ioam6_id_wide': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/keep_addr_on_down': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/max_addresses': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/max_desync_factor': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/mldv1_unsolicited_report_interval': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/mldv2_unsolicited_report_interval': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/mtu': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/ndisc_evict_nocarrier': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/ndisc_notify': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/ndisc_tclass': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/proxy_ndp': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/ra_defrtr_metric': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/regen_max_retry': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/router_solicitation_delay': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/router_solicitation_interval': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/router_solicitation_max_interval': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/router_solicitations': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/rpl_seg_enabled': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/seg6_enabled': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/stable_secret': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/suppress_frag_ndisc': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/temp_prefered_lft': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/temp_valid_lft': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/use_oif_addrs_only': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/eth0/use_tempaddr': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/accept_dad': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/accept_ra': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/accept_ra_defrtr': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/accept_ra_from_local': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/accept_ra_min_hop_limit': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/accept_ra_min_lft': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/accept_ra_mtu': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/accept_ra_pinfo': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/accept_redirects': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/accept_source_route': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/accept_untracked_na': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/addr_gen_mode': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/autoconf': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/dad_transmits': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/disable_ipv6': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/disable_policy': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/drop_unicast_in_l2_multicast': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/drop_unsolicited_na': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/enhanced_dad': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/force_mld_version': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/force_tllao': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/forwarding': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/hop_limit': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/ignore_routes_with_linkdown': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/ioam6_enabled': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/ioam6_id': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/ioam6_id_wide': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/keep_addr_on_down': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/max_addresses': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/max_desync_factor': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/mldv1_unsolicited_report_interval': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/mldv2_unsolicited_report_interval': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/mtu': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/ndisc_evict_nocarrier': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/ndisc_notify': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/ndisc_tclass': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/proxy_ndp': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/ra_defrtr_metric': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/regen_max_retry': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/router_solicitation_delay': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/router_solicitation_interval': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/router_solicitation_max_interval': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/router_solicitations': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/rpl_seg_enabled': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/seg6_enabled': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/stable_secret': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/suppress_frag_ndisc': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/temp_prefered_lft': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/temp_valid_lft': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/use_oif_addrs_only': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/conf/lo/use_tempaddr': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/fib_multipath_hash_fields': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/fib_multipath_hash_policy': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/fib_notify_on_flag_change': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/flowlabel_consistency': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/flowlabel_reflect': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/flowlabel_state_ranges': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/fwmark_reflect': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/icmp/echo_ignore_all': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/icmp/echo_ignore_anycast': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/icmp/echo_ignore_multicast': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/icmp/ratelimit': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/icmp/ratemask': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/idgen_delay': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/idgen_retries': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/ioam6_id': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/ioam6_id_wide': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/ip6frag_high_thresh': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/ip6frag_low_thresh': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/ip6frag_time': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/ip_nonlocal_bind': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/max_dst_opts_length': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/max_dst_opts_number': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/max_hbh_length': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/max_hbh_opts_number': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/neigh/eth0/anycast_delay': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/neigh/eth0/app_solicit': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/neigh/eth0/base_reachable_time': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/neigh/eth0/base_reachable_time_ms': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/neigh/eth0/delay_first_probe_time': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/neigh/eth0/gc_stale_time': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/neigh/eth0/interval_probe_time_ms': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/neigh/eth0/locktime': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/neigh/eth0/mcast_resolicit': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/neigh/eth0/mcast_solicit': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/neigh/eth0/proxy_delay': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/neigh/eth0/proxy_qlen': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/neigh/eth0/retrans_time': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/neigh/eth0/retrans_time_ms': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/neigh/eth0/ucast_solicit': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/neigh/eth0/unres_qlen': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/neigh/eth0/unres_qlen_bytes': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/neigh/lo/anycast_delay': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/neigh/lo/app_solicit': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/neigh/lo/base_reachable_time': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/neigh/lo/base_reachable_time_ms': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/neigh/lo/delay_first_probe_time': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/neigh/lo/gc_stale_time': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/neigh/lo/interval_probe_time_ms': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/neigh/lo/locktime': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/neigh/lo/mcast_resolicit': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/neigh/lo/mcast_solicit': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/neigh/lo/proxy_delay': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/neigh/lo/proxy_qlen': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/neigh/lo/retrans_time': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/neigh/lo/retrans_time_ms': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/neigh/lo/ucast_solicit': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/neigh/lo/unres_qlen': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/neigh/lo/unres_qlen_bytes': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/route/flush': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/route/gc_elasticity': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/route/gc_interval': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/route/gc_min_interval': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/route/gc_min_interval_ms': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/route/gc_thresh': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/route/gc_timeout': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/route/max_size': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/route/min_adv_mss': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/route/mtu_expires': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/route/skip_notify_on_dev_down': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/seg6_flowlabel': Read-only file system
# rm: cannot remove '/proc/sys/net/ipv6/xfrm6_gc_thresh': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_acct': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_buckets': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_checksum': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_count': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_dccp_loose': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_dccp_timeout_closereq': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_dccp_timeout_closing': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_dccp_timeout_open': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_dccp_timeout_partopen': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_dccp_timeout_request': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_dccp_timeout_respond': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_dccp_timeout_timewait': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_events': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_expect_max': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_frag6_high_thresh': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_frag6_low_thresh': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_frag6_timeout': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_generic_timeout': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_gre_timeout': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_gre_timeout_stream': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_icmp_timeout': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_icmpv6_timeout': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_log_invalid': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_max': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_sctp_timeout_closed': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_sctp_timeout_cookie_echoed': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_sctp_timeout_cookie_wait': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_sctp_timeout_established': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_sctp_timeout_heartbeat_sent': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_sctp_timeout_shutdown_ack_sent': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_sctp_timeout_shutdown_recd': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_sctp_timeout_shutdown_sent': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_tcp_be_liberal': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_tcp_ignore_invalid_rst': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_tcp_loose': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_tcp_max_retrans': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_tcp_timeout_close': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_tcp_timeout_close_wait': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_tcp_timeout_established': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_tcp_timeout_fin_wait': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_tcp_timeout_last_ack': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_tcp_timeout_max_retrans': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_tcp_timeout_syn_recv': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_tcp_timeout_syn_sent': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_tcp_timeout_time_wait': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_tcp_timeout_unacknowledged': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_timestamp': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_udp_timeout': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_conntrack_udp_timeout_stream': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_flowtable_tcp_timeout': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_flowtable_udp_timeout': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_hooks_lwtunnel': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_log/0': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_log/1': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_log/10': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_log/2': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_log/3': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_log/4': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_log/5': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_log/6': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_log/7': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_log/8': Read-only file system
# rm: cannot remove '/proc/sys/net/netfilter/nf_log/9': Read-only file system
# rm: cannot remove '/proc/sys/net/unix/max_dgram_qlen': Read-only file system
# rm: cannot remove '/proc/sys/user/max_cgroup_namespaces': Read-only file system
# rm: cannot remove '/proc/sys/user/max_fanotify_groups': Read-only file system
# rm: cannot remove '/proc/sys/user/max_fanotify_marks': Read-only file system
# rm: cannot remove '/proc/sys/user/max_inotify_instances': Read-only file system
# rm: cannot remove '/proc/sys/user/max_inotify_watches': Read-only file system
# rm: cannot remove '/proc/sys/user/max_ipc_namespaces': Read-only file system
# rm: cannot remove '/proc/sys/user/max_mnt_namespaces': Read-only file system
# rm: cannot remove '/proc/sys/user/max_net_namespaces': Read-only file system
# rm: cannot remove '/proc/sys/user/max_pid_namespaces': Read-only file system
# rm: cannot remove '/proc/sys/user/max_time_namespaces': Read-only file system
# rm: cannot remove '/proc/sys/user/max_user_namespaces': Read-only file system
# rm: cannot remove '/proc/sys/user/max_uts_namespaces': Read-only file system
# rm: cannot remove '/proc/sys/vm/admin_reserve_kbytes': Read-only file system
# rm: cannot remove '/proc/sys/vm/compact_memory': Read-only file system
# rm: cannot remove '/proc/sys/vm/compact_unevictable_allowed': Read-only file system
# rm: cannot remove '/proc/sys/vm/compaction_proactiveness': Read-only file system
# rm: cannot remove '/proc/sys/vm/dirty_background_bytes': Read-only file system
# rm: cannot remove '/proc/sys/vm/dirty_background_ratio': Read-only file system
# rm: cannot remove '/proc/sys/vm/dirty_bytes': Read-only file system
# rm: cannot remove '/proc/sys/vm/dirty_expire_centisecs': Read-only file system
# rm: cannot remove '/proc/sys/vm/dirty_ratio': Read-only file system
# rm: cannot remove '/proc/sys/vm/dirty_writeback_centisecs': Read-only file system
# rm: cannot remove '/proc/sys/vm/dirtytime_expire_seconds': Read-only file system
# rm: cannot remove '/proc/sys/vm/drop_caches': Read-only file system
# rm: cannot remove '/proc/sys/vm/extfrag_threshold': Read-only file system
# rm: cannot remove '/proc/sys/vm/hugetlb_optimize_vmemmap': Read-only file system
# rm: cannot remove '/proc/sys/vm/hugetlb_shm_group': Read-only file system
# rm: cannot remove '/proc/sys/vm/laptop_mode': Read-only file system
# rm: cannot remove '/proc/sys/vm/legacy_va_layout': Read-only file system
# rm: cannot remove '/proc/sys/vm/lowmem_reserve_ratio': Read-only file system
# rm: cannot remove '/proc/sys/vm/max_map_count': Read-only file system
# rm: cannot remove '/proc/sys/vm/memory_failure_early_kill': Read-only file system
# rm: cannot remove '/proc/sys/vm/memory_failure_recovery': Read-only file system
# rm: cannot remove '/proc/sys/vm/min_free_kbytes': Read-only file system
# rm: cannot remove '/proc/sys/vm/min_slab_ratio': Read-only file system
# rm: cannot remove '/proc/sys/vm/min_unmapped_ratio': Read-only file system
# rm: cannot remove '/proc/sys/vm/mmap_min_addr': Read-only file system
# rm: cannot remove '/proc/sys/vm/mmap_rnd_bits': Read-only file system
# rm: cannot remove '/proc/sys/vm/mmap_rnd_compat_bits': Read-only file system
# rm: cannot remove '/proc/sys/vm/nr_hugepages': Read-only file system
# rm: cannot remove '/proc/sys/vm/nr_hugepages_mempolicy': Read-only file system
# rm: cannot remove '/proc/sys/vm/nr_overcommit_hugepages': Read-only file system
# rm: cannot remove '/proc/sys/vm/numa_stat': Read-only file system
# rm: cannot remove '/proc/sys/vm/numa_zonelist_order': Read-only file system
# rm: cannot remove '/proc/sys/vm/oom_dump_tasks': Read-only file system
# rm: cannot remove '/proc/sys/vm/oom_kill_allocating_task': Read-only file system
# rm: cannot remove '/proc/sys/vm/overcommit_kbytes': Read-only file system
# rm: cannot remove '/proc/sys/vm/overcommit_memory': Read-only file system
# rm: cannot remove '/proc/sys/vm/overcommit_ratio': Read-only file system
# rm: cannot remove '/proc/sys/vm/page-cluster': Read-only file system
# rm: cannot remove '/proc/sys/vm/page_lock_unfairness': Read-only file system
# rm: cannot remove '/proc/sys/vm/panic_on_oom': Read-only file system
# rm: cannot remove '/proc/sys/vm/percpu_pagelist_high_fraction': Read-only file system
# rm: cannot remove '/proc/sys/vm/stat_interval': Read-only file system
# rm: cannot remove '/proc/sys/vm/stat_refresh': Read-only file system
# rm: cannot remove '/proc/sys/vm/swappiness': Read-only file system
# rm: cannot remove '/proc/sys/vm/unprivileged_userfaultfd': Read-only file system
# rm: cannot remove '/proc/sys/vm/user_reserve_kbytes': Read-only file system
# rm: cannot remove '/proc/sys/vm/vfs_cache_pressure': Read-only file system
# rm: cannot remove '/proc/sys/vm/watermark_boost_factor': Read-only file system
# rm: cannot remove '/proc/sys/vm/watermark_scale_factor': Read-only file system
# rm: cannot remove '/proc/sys/vm/zone_reclaim_mode': Read-only file system
# rm: cannot remove '/proc/tty/ldisc': Operation not permitted
# rm: cannot remove '/proc/tty/driver/serial': Operation not permitted
# rm: cannot remove '/proc/tty/ldiscs': Operation not permitted
# rm: cannot remove '/proc/tty/drivers': Operation not permitted
# rm: cannot remove '/proc/acpi': Operation not permitted
# rm: cannot remove '/proc/kmsg': Operation not permitted
# rm: cannot remove '/proc/misc': Operation not permitted
# rm: cannot remove '/proc/mtrr': Operation not permitted
# rm: cannot remove '/proc/scsi': Operation not permitted
# rm: cannot remove '/proc/iomem': Operation not permitted
# rm: cannot remove '/proc/kcore': Operation not permitted
# rm: cannot remove '/proc/locks': Operation not permitted
# rm: cannot remove '/proc/swaps': Operation not permitted
# rm: cannot remove '/proc/crypto': Operation not permitted
# rm: cannot remove '/proc/driver/rtc': Operation not permitted
# rm: cannot remove '/proc/driver/nvram': Operation not permitted
# rm: cannot remove '/proc/driver/nvidia/gpus/0000:00:04.0/power': Operation not permitted
# rm: cannot remove '/proc/driver/nvidia/gpus/0000:00:04.0/registry': Operation not permitted
# rm: cannot remove '/proc/driver/nvidia/gpus/0000:00:04.0/information': Operation not permitted
# rm: cannot remove '/proc/driver/nvidia/params': Operation not permitted
# rm: cannot remove '/proc/driver/nvidia/patches/README': Operation not permitted
# rm: cannot remove '/proc/driver/nvidia/suspend': Operation not permitted
# rm: cannot remove '/proc/driver/nvidia/version': Operation not permitted
# rm: cannot remove '/proc/driver/nvidia/registry': Operation not permitted
# rm: cannot remove '/proc/driver/nvidia/warnings/README': Operation not permitted
# rm: cannot remove '/proc/driver/nvidia/capabilities/mig/config': Operation not permitted
# rm: cannot remove '/proc/driver/nvidia/capabilities/mig/monitor': Operation not permitted
# rm: cannot remove '/proc/driver/nvidia/capabilities/gpu0/mig': Operation not permitted
# rm: cannot remove '/proc/driver/nvidia/capabilities/fabric-imex-mgmt': Operation not permitted
# rm: cannot remove '/proc/driver/nvidia/suspend_depth': Operation not permitted
# rm: cannot remove '/proc/driver/nvidia-uvm/cpu': Operation not permitted
# rm: cannot remove '/proc/driver/nvidia-uvm/gpus/1': Operation not permitted
# rm: cannot remove '/proc/driver/nvidia-uvm/gpus/UVM-GPU-69ad8e45-99ca-517b-161d-7303a2fd7f51/0/info': Operation not permitted
# rm: cannot remove '/proc/driver/nvidia-caps/mig-minors': Operation not permitted
# rm: cannot remove '/proc/driver/nvidia-caps/sys-minors': Operation not permitted
# rm: cannot remove '/proc/driver/nvidia-caps/nvlink-minors': Operation not permitted
# rm: cannot remove '/proc/driver/nvidia-nvlink/permissions': Operation not permitted
# rm: cannot remove '/proc/driver/nvidia-nvlink/capabilities/fabric-mgmt': Operation not permitted
# rm: cannot remove '/proc/driver/nvidia-nvswitch/devices': Operation not permitted
# rm: cannot remove '/proc/mdstat': Operation not permitted
# rm: cannot remove '/proc/mounts': Operation not permitted
# rm: cannot remove '/proc/uptime': Operation not permitted
# rm: cannot remove '/proc/vmstat': Operation not permitted
# rm: cannot remove '/proc/cgroups': Operation not permitted
# ...
# rm: cannot remove '/proc/47/task/47/attr/keycreate': Operation not permitted
# rm: cannot remove '/proc/47/task/47/attr/sockcreate': Operation not permitted
# rm: cannot remove '/proc/47/task/47/attr/apparmor/current': Operation not permitted
# rm: cannot remove '/proc/47/task/47/attr/apparmor/prev': Operation not permitted
# rm: cannot remove '/proc/47/task/47/attr/apparmor/exec': Operation not permitted
# rm: cannot remove '/proc/47/task/47/wchan': Operation not permitted
# rm: cannot remove '/proc/47/task/47/stack': Operation not permitted
# rm: cannot remove '/proc/47/task/47/schedstat': Operation not permitted
# rm: cannot remove '/proc/47/task/47/cpuset': Operation not permitted
# rm: cannot remove '/proc/47/task/47/cgroup': Operation not permitted
# rm: cannot remove '/proc/47/task/47/oom_score': Operation not permitted
# rm: cannot remove '/proc/47/task/47/oom_adj': Operation not permitted
# rm: cannot remove '/proc/47/task/47/oom_score_adj': Operation not permitted
# rm: cannot remove '/proc/47/task/47/loginuid': Operation not permitted
# rm: cannot remove '/proc/47/task/47/sessionid': Operation not permitted
# rm: cannot remove '/proc/47/task/47/io': Operation not permitted
# rm: cannot remove '/proc/47/task/47/uid_map': Operation not permitted
# rm: cannot remove '/proc/47/task/47/gid_map': Operation not permitted
# rm: cannot remove '/proc/47/task/47/projid_map': Operation not permitted
# rm: cannot remove '/proc/47/task/47/setgroups': Operation not permitted
# rm: cannot remove '/proc/47/task/47/arch_status': Operation not permitted
# rm: cannot remove '/proc/47/fd/0': Operation not permitted
# rm: cannot remove '/proc/47/fd/1': Operation not permitted
# rm: cannot remove '/proc/47/fd/2': Operation not permitted
# rm: cannot remove '/proc/47/map_files/5baa44f08000-5baa44f0a000': Operation not permitted
# rm: cannot remove '/proc/47/map_files/5baa44f0a000-5baa44f14000': Operation not permitted
# rm: cannot remove '/proc/47/map_files/5baa44f14000-5baa44f17000': Operation not permitted
# rm: cannot remove '/proc/47/map_files/5baa44f18000-5baa44f19000': Operation not permitted
# rm: cannot remove '/proc/47/map_files/5baa44f19000-5baa44f1a000': Operation not permitted
# rm: cannot remove '/proc/47/map_files/79cd0547d000-79cd05766000': Operation not permitted
# rm: cannot remove '/proc/47/map_files/79cd05769000-79cd05791000': Operation not permitted
# rm: cannot remove '/proc/47/map_files/79cd05791000-79cd05926000': Operation not permitted
# rm: cannot remove '/proc/47/map_files/79cd05926000-79cd0597e000': Operation not permitted
# rm: cannot remove '/proc/47/map_files/79cd0597e000-79cd0597f000': Operation not permitted
# rm: cannot remove '/proc/47/map_files/79cd0597f000-79cd05983000': Operation not permitted
# rm: cannot remove '/proc/47/map_files/79cd05983000-79cd05985000': Operation not permitted
# rm: cannot remove '/proc/47/map_files/79cd059ab000-79cd059ad000': Operation not permitted
# rm: cannot remove '/proc/47/map_files/79cd059ad000-79cd059d7000': Operation not permitted
# rm: cannot remove '/proc/47/map_files/79cd059d7000-79cd059e2000': Operation not permitted
# rm: cannot remove '/proc/47/map_files/79cd059e3000-79cd059e5000': Operation not permitted
# rm: cannot remove '/proc/47/map_files/79cd059e5000-79cd059e7000': Operation not permitted
# rm: cannot remove '/proc/47/fdinfo/0': Operation not permitted
# rm: cannot remove '/proc/47/fdinfo/1': Operation not permitted
# rm: cannot remove '/proc/47/fdinfo/2': Operation not permitted
# rm: cannot remove '/proc/47/ns/net': Operation not permitted
# rm: cannot remove '/proc/47/ns/uts': Operation not permitted
# rm: cannot remove '/proc/47/ns/ipc': Operation not permitted
# rm: cannot remove '/proc/47/ns/pid': Operation not permitted
# rm: cannot remove '/proc/47/ns/pid_for_children': Operation not permitted
# rm: cannot remove '/proc/47/ns/user': Operation not permitted
# rm: cannot remove '/proc/47/ns/mnt': Operation not permitted
# rm: cannot remove '/proc/47/ns/cgroup': Operation not permitted
# rm: cannot remove '/proc/47/ns/time': Operation not permitted
# rm: cannot remove '/proc/47/ns/time_for_children': Operation not permitted
# rm: cannot remove '/proc/47/net/arp': Operation not permitted
# rm: cannot remove '/proc/47/net/dev': Operation not permitted
# rm: cannot remove '/proc/47/net/raw': Operation not permitted
# rm: cannot remove '/proc/47/net/tcp': Operation not permitted
# rm: cannot remove '/proc/47/net/udp': Operation not permitted
# rm: cannot remove '/proc/47/net/icmp': Operation not permitted
# rm: cannot remove '/proc/47/net/igmp': Operation not permitted
# rm: cannot remove '/proc/47/net/raw6': Operation not permitted
# rm: cannot remove '/proc/47/net/snmp': Operation not permitted
# rm: cannot remove '/proc/47/net/stat/rt_cache': Operation not permitted
# rm: cannot remove '/proc/47/net/stat/synproxy': Operation not permitted
# rm: cannot remove '/proc/47/net/stat/nf_conntrack': Operation not permitted
# rm: cannot remove '/proc/47/net/tcp6': Operation not permitted
# rm: cannot remove '/proc/47/net/udp6': Operation not permitted
# rm: cannot remove '/proc/47/net/unix': Operation not permitted
# rm: cannot remove '/proc/47/net/icmp6': Operation not permitted
# rm: cannot remove '/proc/47/net/igmp6': Operation not permitted
# rm: cannot remove '/proc/47/net/ptype': Operation not permitted
# rm: cannot remove '/proc/47/net/route': Operation not permitted
# rm: cannot remove '/proc/47/net/snmp6': Operation not permitted
# rm: cannot remove '/proc/47/net/packet': Operation not permitted
# rm: cannot remove '/proc/47/net/psched': Operation not permitted
# rm: cannot remove '/proc/47/net/netlink': Operation not permitted
# rm: cannot remove '/proc/47/net/netstat': Operation not permitted
# rm: cannot remove '/proc/47/net/rt_acct': Operation not permitted
# rm: cannot remove '/proc/47/net/udplite': Operation not permitted
# rm: cannot remove '/proc/47/net/anycast6': Operation not permitted
# rm: cannot remove '/proc/47/net/fib_trie': Operation not permitted
# rm: cannot remove '/proc/47/net/if_inet6': Operation not permitted
# rm: cannot remove '/proc/47/net/mcfilter': Operation not permitted
# rm: cannot remove '/proc/47/net/rt_cache': Operation not permitted
# rm: cannot remove '/proc/47/net/sockstat': Operation not permitted
# rm: cannot remove '/proc/47/net/tls_stat': Operation not permitted
# rm: cannot remove '/proc/47/net/udplite6': Operation not permitted
# rm: cannot remove '/proc/47/net/dev_mcast': Operation not permitted
# rm: cannot remove '/proc/47/net/dev_snmp6/lo': Operation not permitted
# rm: cannot remove '/proc/47/net/dev_snmp6/eth0': Operation not permitted
# rm: cannot remove '/proc/47/net/ip_mr_vif': Operation not permitted
# rm: cannot remove '/proc/47/net/mcfilter6': Operation not permitted
# rm: cannot remove '/proc/47/net/netfilter/nf_log': Operation not permitted
# rm: cannot remove '/proc/47/net/netfilter/nfnetlink_log': Operation not permitted
# rm: cannot remove '/proc/47/net/netfilter/nfnetlink_queue': Operation not permitted
# rm: cannot remove '/proc/47/net/protocols': Operation not permitted
# rm: cannot remove '/proc/47/net/rt6_stats': Operation not permitted
# rm: cannot remove '/proc/47/net/sockstat6': Operation not permitted
# rm: cannot remove '/proc/47/net/xfrm_stat': Operation not permitted
# rm: cannot remove '/proc/47/net/ipv6_route': Operation not permitted
# rm: cannot remove '/proc/47/net/ip_mr_cache': Operation not permitted
# rm: cannot remove '/proc/47/net/fib_triestat': Operation not permitted
# rm: cannot remove '/proc/47/net/nf_conntrack': Operation not permitted
# rm: cannot remove '/proc/47/net/softnet_stat': Operation not permitted
# rm: cannot remove '/proc/47/net/ip6_flowlabel': Operation not permitted
# rm: cannot remove '/proc/47/net/ip_tables_names': Operation not permitted
# rm: cannot remove '/proc/47/net/ip6_tables_names': Operation not permitted
# rm: cannot remove '/proc/47/net/ip_tables_matches': Operation not permitted
# rm: cannot remove '/proc/47/net/ip_tables_targets': Operation not permitted
# rm: cannot remove '/proc/47/net/ip6_tables_matches': Operation not permitted
# rm: cannot remove '/proc/47/net/ip6_tables_targets': Operation not permitted
# rm: cannot remove '/proc/47/net/nf_conntrack_expect': Operation not permitted
# rm: cannot remove '/proc/47/environ': Operation not permitted
# rm: cannot remove '/proc/47/auxv': Operation not permitted
# rm: cannot remove '/proc/47/status': Operation not permitted
# rm: cannot remove '/proc/47/personality': Operation not permitted
# rm: cannot remove '/proc/47/limits': Operation not permitted
# rm: cannot remove '/proc/47/timens_offsets': Operation not permitted
# rm: cannot remove '/proc/47/comm': Operation not permitted
# rm: cannot remove '/proc/47/syscall': Operation not permitted
# rm: cannot remove '/proc/47/cmdline': Operation not permitted
# rm: cannot remove '/proc/47/stat': Operation not permitted
# rm: cannot remove '/proc/47/statm': Operation not permitted
# rm: cannot remove '/proc/47/maps': Operation not permitted
# rm: cannot remove '/proc/47/numa_maps': Operation not permitted
# rm: cannot remove '/proc/47/mem': Operation not permitted
# rm: cannot remove '/proc/47/cwd': Operation not permitted
# rm: cannot remove '/proc/47/root': Operation not permitted
# rm: cannot remove '/proc/47/exe': Operation not permitted
# rm: cannot remove '/proc/47/mounts': Operation not permitted
# rm: cannot remove '/proc/47/mountinfo': Operation not permitted
# rm: cannot remove '/proc/47/mountstats': Operation not permitted
# rm: cannot remove '/proc/47/clear_refs': Operation not permitted
# rm: cannot remove '/proc/47/smaps': Operation not permitted
# rm: cannot remove '/proc/47/smaps_rollup': Operation not permitted
# rm: cannot remove '/proc/47/pagemap': Operation not permitted
# rm: cannot remove '/proc/47/attr/current': Operation not permitted
# rm: cannot remove '/proc/47/attr/prev': Operation not permitted
# rm: cannot remove '/proc/47/attr/exec': Operation not permitted
# rm: cannot remove '/proc/47/attr/fscreate': Operation not permitted
# rm: cannot remove '/proc/47/attr/keycreate': Operation not permitted
# rm: cannot remove '/proc/47/attr/sockcreate': Operation not permitted
# rm: cannot remove '/proc/47/attr/apparmor/current': Operation not permitted
# rm: cannot remove '/proc/47/attr/apparmor/prev': Operation not permitted
# rm: cannot remove '/proc/47/attr/apparmor/exec': Operation not permitted
# rm: cannot remove '/proc/47/wchan': Operation not permitted
# rm: cannot remove '/proc/47/stack': Operation not permitted
# rm: cannot remove '/proc/47/schedstat': Operation not permitted
# rm: cannot remove '/proc/47/cpuset': Operation not permitted
# rm: cannot remove '/proc/47/cgroup': Operation not permitted
# rm: cannot remove '/proc/47/oom_score': Operation not permitted
# rm: cannot remove '/proc/47/oom_adj': Operation not permitted
# rm: cannot remove '/proc/47/oom_score_adj': Operation not permitted
# rm: cannot remove '/proc/47/loginuid': Operation not permitted
# rm: cannot remove '/proc/47/sessionid': Operation not permitted
# rm: cannot remove '/proc/47/coredump_filter': Operation not permitted
# rm: cannot remove '/proc/47/io': Operation not permitted
# rm: cannot remove '/proc/47/uid_map': Operation not permitted
# rm: cannot remove '/proc/47/gid_map': Operation not permitted
# rm: cannot remove '/proc/47/projid_map': Operation not permitted
# rm: cannot remove '/proc/47/setgroups': Operation not permitted
# rm: cannot remove '/proc/47/timers': Operation not permitted
# rm: cannot remove '/proc/47/timerslack_ns': Operation not permitted
# rm: cannot remove '/proc/47/arch_status': Operation not permitted
# rm: cannot remove '/proc/64/task/64/fd': Operation not permitted
# rm: cannot remove '/proc/64/task/64/fdinfo': Operation not permitted
# rm: cannot remove '/proc/64/task/64/ns/net': Operation not permitted
# rm: cannot remove '/proc/64/task/64/ns/uts': Operation not permitted
# rm: cannot remove '/proc/64/task/64/ns/ipc': Operation not permitted
# rm: cannot remove '/proc/64/task/64/ns/pid': Operation not permitted
# rm: cannot remove '/proc/64/task/64/ns/pid_for_children': Operation not permitted
# rm: cannot remove '/proc/64/task/64/ns/user': Operation not permitted
# rm: cannot remove '/proc/64/task/64/ns/mnt': Operation not permitted
# rm: cannot remove '/proc/64/task/64/ns/cgroup': Operation not permitted
# rm: cannot remove '/proc/64/task/64/ns/time': Operation not permitted
# rm: cannot remove '/proc/64/task/64/ns/time_for_children': Operation not permitted
# rm: cannot remove '/proc/64/task/64/net': Operation not permitted
# rm: cannot remove '/proc/64/task/64/environ': Operation not permitted
# rm: cannot remove '/proc/64/task/64/auxv': Operation not permitted
# rm: cannot remove '/proc/64/task/64/status': Operation not permitted
# rm: cannot remove '/proc/64/task/64/personality': Operation not permitted
# rm: cannot remove '/proc/64/task/64/limits': Operation not permitted
# rm: cannot remove '/proc/64/task/64/comm': Operation not permitted
# rm: cannot remove '/proc/64/task/64/syscall': Operation not permitted
# rm: cannot remove '/proc/64/task/64/cmdline': Operation not permitted
# rm: cannot remove '/proc/64/task/64/stat': Operation not permitted
# rm: cannot remove '/proc/64/task/64/statm': Operation not permitted
# rm: cannot remove '/proc/64/task/64/maps': Operation not permitted
# rm: cannot remove '/proc/64/task/64/children': Operation not permitted
# rm: cannot remove '/proc/64/task/64/numa_maps': Operation not permitted
# rm: cannot remove '/proc/64/task/64/mem': Operation not permitted
# rm: cannot remove '/proc/64/task/64/cwd': Operation not permitted
# rm: cannot remove '/proc/64/task/64/root': Operation not permitted
# rm: cannot remove '/proc/64/task/64/exe': Operation not permitted
# rm: cannot remove '/proc/64/task/64/mounts': Operation not permitted
# rm: cannot remove '/proc/64/task/64/mountinfo': Operation not permitted
# rm: cannot remove '/proc/64/task/64/clear_refs': Operation not permitted
# rm: cannot remove '/proc/64/task/64/smaps': Operation not permitted
# rm: cannot remove '/proc/64/task/64/smaps_rollup': Operation not permitted
# rm: cannot remove '/proc/64/task/64/pagemap': Operation not permitted
# rm: cannot remove '/proc/64/task/64/attr/current': Operation not permitted
# rm: cannot remove '/proc/64/task/64/attr/prev': Operation not permitted
# rm: cannot remove '/proc/64/task/64/attr/exec': Operation not permitted
# rm: cannot remove '/proc/64/task/64/attr/fscreate': Operation not permitted
# rm: cannot remove '/proc/64/task/64/attr/keycreate': Operation not permitted
# rm: cannot remove '/proc/64/task/64/attr/sockcreate': Operation not permitted
# rm: cannot remove '/proc/64/task/64/attr/apparmor/current': Operation not permitted
# rm: cannot remove '/proc/64/task/64/attr/apparmor/prev': Operation not permitted
# rm: cannot remove '/proc/64/task/64/attr/apparmor/exec': Operation not permitted
# rm: cannot remove '/proc/64/task/64/wchan': Operation not permitted
# rm: cannot remove '/proc/64/task/64/stack': Operation not permitted
# rm: cannot remove '/proc/64/task/64/schedstat': Operation not permitted
# rm: cannot remove '/proc/64/task/64/cpuset': Operation not permitted
# rm: cannot remove '/proc/64/task/64/cgroup': Operation not permitted
# rm: cannot remove '/proc/64/task/64/oom_score': Operation not permitted
# rm: cannot remove '/proc/64/task/64/oom_adj': Operation not permitted
# rm: cannot remove '/proc/64/task/64/oom_score_adj': Operation not permitted
# rm: cannot remove '/proc/64/task/64/loginuid': Operation not permitted
# rm: cannot remove '/proc/64/task/64/sessionid': Operation not permitted
# rm: cannot remove '/proc/64/task/64/io': Operation not permitted
# rm: cannot remove '/proc/64/task/64/uid_map': Operation not permitted
# rm: cannot remove '/proc/64/task/64/gid_map': Operation not permitted
# rm: cannot remove '/proc/64/task/64/projid_map': Operation not permitted
# rm: cannot remove '/proc/64/task/64/setgroups': Operation not permitted
# rm: cannot remove '/proc/64/task/64/arch_status': Operation not permitted
# rm: cannot remove '/proc/64/fd': Operation not permitted
# rm: cannot remove '/proc/64/map_files': Operation not permitted
# rm: cannot remove '/proc/64/fdinfo': Operation not permitted

# %%
import numpy as np
import matplotlib.pyplot as plt

w = 1000
h = 1000
fig = plt.figure(figsize=(8, 8))
columns = 100
rows = 100
for i in range(1, columns*rows +1):
    img = np.random.randint(10, size=(h,w))
    fig.add_subplot(rows, columns, i)
    plt.imshow(X_train[i])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-c9853d147fc2> in <cell line: 0>()
#       8 rows = 100
#       9 for i in range(1, columns*rows +1):
# ---> 10     img = np.random.randint(10, size=(h,w))
#      11     fig.add_subplot(rows, columns, i)
#      12     plt.imshow(X_train[i])
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x7c4535fa8400> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/matplotlib_inline/backend_inline.py in flush_figures()
#     124             # ignore the tracking, just draw and close all figures
#     125             try:
# --> 126                 return show(True)
#     127             except Exception as e:
#     128                 # safely show traceback if in IPython, else raise
#
# /usr/local/lib/python3.11/dist-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      88     try:
#      89         for figure_manager in Gcf.get_all_fig_managers():
# ---> 90             display(
#      91                 figure_manager.canvas.figure,
#      92                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2153                 # so that we can inject the orientation
#    2154                 with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2155                     self.figure.draw(renderer)
#    2156             if bbox_inches:
#    2157                 if bbox_inches == "tight":
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      92     @wraps(draw)
#      93     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94         result = draw(artist, renderer, *args, **kwargs)
#      95         if renderer._rasterizing:
#      96             renderer.stop_rasterizing()
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    3255
#    3256                 self.patch.draw(renderer)
# -> 3257                 mimage._draw_list_compositing_images(
#    3258                     renderer, self, artists, self.suppressComposite)
#    3259
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132     if not_composite or not has_images:
#     133         for a in artists:
# --> 134             a.draw(renderer)
#     135     else:
#     136         # Composite any adjacent images together
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3179             _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
#    3180
# -> 3181         mimage._draw_list_compositing_images(
#    3182             renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3183
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132     if not_composite or not has_images:
#     133         for a in artists:
# --> 134             a.draw(renderer)
#     135     else:
#     136         # Composite any adjacent images together
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axis.py in draw(self, renderer)
#    1417
#    1418         for tick in ticks_to_draw:
# -> 1419             tick.draw(renderer)
#    1420
#    1421         # Shift label away from axes to avoid overlapping ticklabels.
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axis.py in draw(self, renderer)
#     274         for artist in [self.gridline, self.tick1line, self.tick2line,
#     275                        self.label1, self.label2]:
# --> 276             artist.draw(renderer)
#     277         renderer.close_group(self.__name__)
#     278         self.stale = False
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/lines.py in draw(self, renderer)
#     816
#     817             ec_rgba = mcolors.to_rgba(
# --> 818                 self.get_markeredgecolor(), self._alpha)
#     819             fc_rgba = mcolors.to_rgba(
#     820                 self._get_markerfacecolor(), self._alpha)
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/lines.py in get_markeredgecolor(self)
#     940         return self._marker.get_marker()
#     941
# --> 942     def get_markeredgecolor(self):
#     943         """
#     944         Return the marker edge color.
#
# KeyboardInterrupt:
